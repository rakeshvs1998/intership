# %%
import numpy as np
import pandas as pd

from sklearn import preprocessing
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import linear_model 
from sklearn.model_selection import train_test_split
from mpl_toolkits import mplot3d
# %matplotlib inline
gasprice=pd.read_csv("qwe.csv")
gasprices=gasprice.drop(['CCCC','DDDD','BBBB','EEEE'],axis=1)

# %%
type(gasprices)
# Out:
# pandas.core.frame.DataFrame

# %%
gasprices
# Out:
#           S.NO DATE OF INITAL ANALYSES DATE OF FINAL ANALSIS  MACRO REGION  \
# 0            0              09-05-2004            15-05-2004  CENTRO OESTE
# 1            1              09-05-2004            15-05-2004  CENTRO OESTE
# 2            2              09-05-2004            15-05-2004  CENTRO OESTE
# 3            3              09-05-2004            15-05-2004  CENTRO OESTE
# 4            4              09-05-2004            15-05-2004      NORDESTE
# 5            5              09-05-2004            15-05-2004      NORDESTE
# 6            6              09-05-2004            15-05-2004      NORDESTE
# 7            7              09-05-2004            15-05-2004      NORDESTE
# 8            8              09-05-2004            15-05-2004      NORDESTE
# 9            9              09-05-2004            15-05-2004      NORDESTE
# 10          10              09-05-2004            15-05-2004      NORDESTE
# ...

# %%
gasprices["STATE"].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
df = gasprices

# %%
gasprices
# Out:
#           S.NO DATE OF INITAL ANALYSES DATE OF FINAL ANALSIS  MACRO REGION  \
# 0            0              09-05-2004            15-05-2004  CENTRO OESTE
# 1            1              09-05-2004            15-05-2004  CENTRO OESTE
# 2            2              09-05-2004            15-05-2004  CENTRO OESTE
# 3            3              09-05-2004            15-05-2004  CENTRO OESTE
# 4            4              09-05-2004            15-05-2004      NORDESTE
# 5            5              09-05-2004            15-05-2004      NORDESTE
# 6            6              09-05-2004            15-05-2004      NORDESTE
# 7            7              09-05-2004            15-05-2004      NORDESTE
# 8            8              09-05-2004            15-05-2004      NORDESTE
# 9            9              09-05-2004            15-05-2004      NORDESTE
# 10          10              09-05-2004            15-05-2004      NORDESTE
# ...

# %%
# print(df.apply(lambda x:pd.factorize(x)[0])

# %%
df
# Out:
#           S.NO DATE OF INITAL ANALYSES DATE OF FINAL ANALSIS  MACRO REGION  \
# 0            0              09-05-2004            15-05-2004  CENTRO OESTE
# 1            1              09-05-2004            15-05-2004  CENTRO OESTE
# 2            2              09-05-2004            15-05-2004  CENTRO OESTE
# 3            3              09-05-2004            15-05-2004  CENTRO OESTE
# 4            4              09-05-2004            15-05-2004      NORDESTE
# 5            5              09-05-2004            15-05-2004      NORDESTE
# 6            6              09-05-2004            15-05-2004      NORDESTE
# 7            7              09-05-2004            15-05-2004      NORDESTE
# 8            8              09-05-2004            15-05-2004      NORDESTE
# 9            9              09-05-2004            15-05-2004      NORDESTE
# 10          10              09-05-2004            15-05-2004      NORDESTE
# ...

# %%
le=preprocessing.LabelEncoder()

# %%
df['STATE']=le.fit_transform(df['STATE'])

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           S.NO DATE OF INITAL ANALYSES DATE OF FINAL ANALSIS  MACRO REGION  \
# 0            0              09-05-2004            15-05-2004  CENTRO OESTE
# 1            1              09-05-2004            15-05-2004  CENTRO OESTE
# 2            2              09-05-2004            15-05-2004  CENTRO OESTE
# 3            3              09-05-2004            15-05-2004  CENTRO OESTE
# 4            4              09-05-2004            15-05-2004      NORDESTE
# 5            5              09-05-2004            15-05-2004      NORDESTE
# 6            6              09-05-2004            15-05-2004      NORDESTE
# 7            7              09-05-2004            15-05-2004      NORDESTE
# 8            8              09-05-2004            15-05-2004      NORDESTE
# 9            9              09-05-2004            15-05-2004      NORDESTE
# 10          10              09-05-2004            15-05-2004      NORDESTE
# ...

# %%
df['KIND OF PRODUCT']=le.fit_transform(df['KIND OF PRODUCT'])df.columns
# Out:
#   File "<ipython-input-105-1e8da725de2e>", line 1
#     df['KIND OF PRODUCT']=le.fit_transform(df['KIND OF PRODUCT'])df.columns
#                                                                   ^
# SyntaxError: invalid syntax

# %%
df.columns
# Out:
# Index(['S.NO', 'DATE OF INITAL ANALYSES', 'DATE OF FINAL ANALSIS',
#        'MACRO REGION', 'STATE', 'KIND OF PRODUCT', 'NUMBER OF GAS STATION',
#        'MEASUREMENT UNIT', 'MEAN MARKET VALUE', 'MIN PRICES OBSERVED',
#        'MAX PRICES OBSERVED', 'MEAN PRICES MARGIN', 'MEAN DISTRIBUTION PRICES',
#        'DISTRIBUTION MIN PRICES', 'DISTRIBUTION MAX PRICES', 'MONTH', 'YEAR'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# S.NO                        0
# DATE OF INITAL ANALYSES     0
# DATE OF FINAL ANALSIS       0
# MACRO REGION                0
# STATE                       0
# KIND OF PRODUCT             0
# NUMBER OF GAS STATION       0
# MEASUREMENT UNIT            0
# MEAN MARKET VALUE           0
# MIN PRICES OBSERVED         0
# MAX PRICES OBSERVED         0
# MEAN PRICES MARGIN          0
# MEAN DISTRIBUTION PRICES    0
# DISTRIBUTION MIN PRICES     0
# DISTRIBUTION MAX PRICES     0
# MONTH                       0
# YEAR                        0
# dtype: int64

# %%
df
# Out:
#           S.NO DATE OF INITAL ANALYSES DATE OF FINAL ANALSIS  MACRO REGION  \
# 0            0              09-05-2004            15-05-2004  CENTRO OESTE
# 1            1              09-05-2004            15-05-2004  CENTRO OESTE
# 2            2              09-05-2004            15-05-2004  CENTRO OESTE
# 3            3              09-05-2004            15-05-2004  CENTRO OESTE
# 4            4              09-05-2004            15-05-2004      NORDESTE
# 5            5              09-05-2004            15-05-2004      NORDESTE
# 6            6              09-05-2004            15-05-2004      NORDESTE
# 7            7              09-05-2004            15-05-2004      NORDESTE
# 8            8              09-05-2004            15-05-2004      NORDESTE
# 9            9              09-05-2004            15-05-2004      NORDESTE
# 10          10              09-05-2004            15-05-2004      NORDESTE
# ...

# %%
df['DATE OF INITAL ANALYSES']=le.fit_transform(df['DATE OF INITAL ANALYSES'])

# %%
df['DATE OF FINAL ANALSIS']=le.fit_transform(df['DATE OF FINAL ANALSIS'])

# %%
df['MACRO REGION']=le.fit_transform(df['MACRO REGION'])

# %%
df['MEASUREMENT UNIT']=le.fit_transform(df['MEASUREMENT UNIT'])

# %%
#df['Vehicle Size']=le.fit_transform(df['Vehicle Size'])

# %%
df['MONTH']=le.fit_transform(df['MONTH'])

# %%
df['YEAR']=le.fit_transform(df['YEAR'])

# %%
df
# Out:
#           S.NO  DATE OF INITAL ANALYSES  DATE OF FINAL ANALSIS  MACRO REGION  \
# 0            0                      214                    369             0
# 1            1                      214                    369             0
# 2            2                      214                    369             0
# 3            3                      214                    369             0
# 4            4                      214                    369             1
# 5            5                      214                    369             1
# 6            6                      214                    369             1
# 7            7                      214                    369             1
# 8            8                      214                    369             1
# 9            9                      214                    369             1
# 10          10                      214                    369             1
# ...

# %%
data2=df.corr('pearson')

# %%
abs(data2)
# Out:
#                              S.NO  DATE OF INITAL ANALYSES  \
# S.NO                     1.000000                 0.000108
# DATE OF INITAL ANALYSES  0.000108                 1.000000
# DATE OF FINAL ANALSIS    0.000567                 0.053476
# MACRO REGION             0.002384                 0.000097
# STATE                    0.002562                 0.000167
# NUMBER OF GAS STATION    0.170455                 0.002257
# MEASUREMENT UNIT         0.044301                 0.000267
# MEAN MARKET VALUE        0.122753                 0.000077
# MIN PRICES OBSERVED      0.118147                 0.000037
# MAX PRICES OBSERVED      0.128449                 0.000259
# MONTH                    0.030138                 0.046315
# YEAR                     0.874938                 0.009096
#
#                          DATE OF FINAL ANALSIS  MACRO REGION     STATE  \
# S.NO                                  0.000567      0.002384  0.002562
# ...

# %%
x=df['DATE OF INITAL ANALYSES']
y=df['DATE OF FINAL ANALSIS']

# %%
plt.plot(x,y,'r.')
plt.show()

# %%
df.corr()
# Out:
#                              S.NO  DATE OF INITAL ANALYSES  \
# S.NO                     1.000000                 0.000108
# DATE OF INITAL ANALYSES  0.000108                 1.000000
# DATE OF FINAL ANALSIS   -0.000567                 0.053476
# MACRO REGION             0.002384                 0.000097
# STATE                    0.002562                -0.000167
# NUMBER OF GAS STATION   -0.170455                -0.002257
# MEASUREMENT UNIT         0.044301                -0.000267
# MEAN MARKET VALUE        0.122753                -0.000077
# MIN PRICES OBSERVED      0.118147                 0.000037
# MAX PRICES OBSERVED      0.128449                -0.000259
# MONTH                   -0.030138                 0.046315
# YEAR                     0.874938                -0.009096
#
#                          DATE OF FINAL ANALSIS  MACRO REGION     STATE  \
# S.NO                                 -0.000567      0.002384  0.002562
# ...

# %%
abs(df.corr())
# Out:
#                              S.NO  DATE OF INITAL ANALYSES  \
# S.NO                     1.000000                 0.000108
# DATE OF INITAL ANALYSES  0.000108                 1.000000
# DATE OF FINAL ANALSIS    0.000567                 0.053476
# MACRO REGION             0.002384                 0.000097
# STATE                    0.002562                 0.000167
# NUMBER OF GAS STATION    0.170455                 0.002257
# MEASUREMENT UNIT         0.044301                 0.000267
# MEAN MARKET VALUE        0.122753                 0.000077
# MIN PRICES OBSERVED      0.118147                 0.000037
# MAX PRICES OBSERVED      0.128449                 0.000259
# MONTH                    0.030138                 0.046315
# YEAR                     0.874938                 0.009096
#
#                          DATE OF FINAL ANALSIS  MACRO REGION     STATE  \
# S.NO                                  0.000567      0.002384  0.002562
# ...

# %%
abs(data2['DATE OF INITAL ANALYSES']).sort_values()
# Out:
# MIN PRICES OBSERVED        0.000037
# MEAN MARKET VALUE          0.000077
# MACRO REGION               0.000097
# S.NO                       0.000108
# STATE                      0.000167
# MAX PRICES OBSERVED        0.000259
# MEASUREMENT UNIT           0.000267
# NUMBER OF GAS STATION      0.002257
# YEAR                       0.009096
# MONTH                      0.046315
# DATE OF FINAL ANALSIS      0.053476
# DATE OF INITAL ANALYSES    1.000000
# Name: DATE OF INITAL ANALYSES, dtype: float64

# %%
X1=data2["DATE OF INITAL ANALYSES"]
X2=data2["DATE OF FINAL ANALSIS"]
Y=data2["MACRO REGION"]
X1 = np.array((X1 - X1.min())-(X1.max() - X1.min()))
X2 = np.array((X2 - X2.min())-(X2.max() - X2.min()))
Y = np.array((Y - Y.min())-(Y.max() - Y.min()))
x1_train, x1_test, x2_train, x2_test, y_train, y_test = train_test_split(X1, X2, Y, test_size=0.2)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1_train, x2_train, y_train, 'g.')

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.plot(x1_test, x2_test, y_test, 'g.')

# %%
def hypothesis(a,b,c,x):
    return a * x + b * np.power(x, 2) + c
def error(a,b,c,x,y):
    e = 0
    m = len(x)
    for i in range(m):
        e += np.power((hypothesis(a,b,c,x[i]) - y[i]), 2)
    
    return (1/(2*m)) * e

# %%
def step_gradient(a,b,c,x,y,learning_rate):
    grad_a = 0
    grad_b = 0
    grad_c = 0
    m = len(x)
    for i in range(m):
        grad_a += 1/m * (hypothesis(a,b,c,x[i]) - y[i]) * x[i]
        grad_b += 1/m * (hypothesis(a,b,c,x[i]) - y[i]) * np.power(x[i], 2)
        grad_c += 1/m * (hypothesis(a,b,c,x[i]) - y[i])
        
    a = a - (grad_a * learning_rate)
    b = b - (grad_b * learning_rate)
    c = c - (grad_c * learning_rate)
    
    return a, b, c

# %%
def descend(initial_a, initial_b, initial_c, x, y, learning_rate, iterations):
    a = initial_a
    b = initial_b
    c = initial_c
    for i in range(iterations):
        e = error(a, b, c, x, y)
        if i % 1000 == 0:
            print(f"Error: {e}, a: {a}, b: {b}, c: {c}")
        
        a, b, c = step_gradient(a, b, c, x, y, learning_rate)

    return a, b, c
a = 0
b = 1
c = 1
learning_rate = 0.5
iterations = 10000

final_a, final_b, final_c = descend(a, b, c, x1_train, y_train, learning_rate, iterations)
# Out:
# Error: 3.794751305059195, a: 0, b: 1, c: 1
# Error: 0.04948256544241189, a: 0.7005419445836825, b: 0.8917392333819301, c: -1.0153766957796535
# Error: 0.049210710761217795, a: 0.9605865264051712, b: 1.1528608751109233, c: -1.0138498886940293
# Error: 0.04899029171457337, a: 1.1947418097465519, b: 1.3879859893407263, c: -1.012475086176562
# Error: 0.04881157654251807, a: 1.4055852594836442, b: 1.5997027163631252, c: -1.0112371550850499
# Error: 0.04866667476016767, a: 1.5954377354246931, b: 1.7903415285883004, c: -1.0101224688898613
# Error: 0.048549188783533155, a: 1.7663890391805854, b: 1.9620008832257811, c: -1.0091187576798717
# Error: 0.048453931468668776, a: 1.9203209176613998, b: 2.116570321057524, c: -1.0082149731013899
# Error: 0.04837669709317045, a: 2.0589277764102936, b: 2.2557512655628593, c: -1.0074011667433744
# Error: 0.04831407566858898, a: 2.183735330776824, b: 2.3810757513417666, c: -1.006668380630272

# %%
print(error(a, b, c, x1_train, y_train))
print(error(final_a, final_b, final_c, x1_train, y_train))
print(error(final_a, final_b, final_c, x1_test, y_test))
# Out:
# 3.794751305059195
# 0.04826330238543218
# 0.013612774297947383

# %%
plt.plot(x1_train, y_train, 'r.', x1_train, hypothesis(a, b, c, x1_train), 'g.', x1_train, hypothesis(final_a, final_b, final_c, x1_train), 'b.', )

# %%
plt.plot(x1_test, y_test, 'r.', x1_test, hypothesis(final_a, final_b, final_c, x1_test), 'g.')
